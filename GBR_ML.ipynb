# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.preprocessing import LabelEncoder

# %%
GData= pd.read_csv('game_data_by_team_apr12.csv',encoding= 'latin1',low_memory=False)

# %%
GData
# Out:
#            Date                  Team Home_Away              Opponent  \
# 0     2/13/2022    Cincinnati Bengals      Home      Los Angeles Rams
# 1     2/13/2022      Los Angeles Rams      Away    Cincinnati Bengals
# 2     1/30/2022    Kansas City Chiefs      Home    Cincinnati Bengals
# 3     1/30/2022    Cincinnati Bengals      Away    Kansas City Chiefs
# 4     1/30/2022      Los Angeles Rams      Home   San Francisco 49ers
# ...         ...                   ...       ...                   ...
# 2705  9/10/2017       Oakland Raiders      Away      Tennessee Titans
# 2706  9/10/2017   Washington Redskins      Home   Philadelphia Eagles
# 2707  9/10/2017   Philadelphia Eagles      Away   Washington Redskins
# 2708   9/7/2017  New England Patriots      Home    Kansas City Chiefs
# 2709   9/7/2017    Kansas City Chiefs      Away  New England Patriots
#
#       Team_Score  Opponent_Score winner  Wins_Last_8   Team_ML  \
# ...

# %%
X= GData[['Wins_Last_8', 'sentiment_past_week', 'Home_Away']]
y= GData['Team_ML']

X['Home_Away']= X['Home_Away'].map({'Home': 1,'Away': 0})

X_train,X_test,y_train,y_test= train_test_split(X,y,test_size= 0.6,random_state=42)

G= GradientBoostingRegressor(random_state=0)

G.fit(X_train, y_train)

Pred= G.predict(X_test)

# %%
for actual,predicted in zip(y_test, Pred):
    print(f'Actual: {actual}, Predicted: {predicted}')
# Out:
# Actual: 2.555, Predicted: 2.940900839948261
# Actual: 1.195909091, Predicted: 2.163819344590249
# Actual: 1.331666667, Predicted: 1.5813840144081621
# Actual: 4.3, Predicted: 3.0327818218692326
# Actual: 2.35, Predicted: 2.991680567054486
# Actual: 3.35, Predicted: 5.389197812913595
# Actual: 2.895, Predicted: 4.040395110680702
# Actual: 1.163333333, Predicted: 1.4000668259636992
# Actual: 1.5, Predicted: 1.7227998502006494
# Actual: 2.375, Predicted: 2.783904323706183
# Actual: 2.295, Predicted: 3.0327818218692326
# Actual: 7.125, Predicted: 2.783904323706183
# Actual: 2.55, Predicted: 2.4899141768014195
# Actual: 1.502, Predicted: 2.783904323706183
# Actual: 2.05, Predicted: 2.5982426138629537
# Actual: 1.4, Predicted: 3.784240283028834
# Actual: 2.0, Predicted: 3.842014491559488
# Actual: 1.46755814, Predicted: 1.450713170390086
# Actual: 2.275, Predicted: 2.0077469544781894
# Actual: 1.8, Predicted: 1.456625080556938
# Actual: 4.875, Predicted: 2.5083348186800145
# ...
